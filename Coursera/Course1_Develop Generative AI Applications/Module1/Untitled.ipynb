# %%
import os
print(os.getenc
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-bd0b11f43583> in <module>
#       1 import os
# ----> 2 print(os.nv("OPENAI_API_KEY"))
#
# AttributeError: module 'os' has no attribute 'nv'
